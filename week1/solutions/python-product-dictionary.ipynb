# %% [markdown]
# # Build a Product Dictionary in Python
#
# Python dictionaries organize information as key-value pairs. They are useful for representing structured records such as products, users, configuration settings, and API responses.
#
# In this tutorial, we will create and manage a laptop product dictionary and then build a second dictionary for a mobile phone.

# %% [markdown]
# ## What You Will Learn
#
# By the end of this tutorial, you will know how to:
#
# - Create and display a dictionary
# - Access values using keys
# - Change existing values
# - Add new key-value pairs
# - Remove dictionary data
# - Use `keys()`, `values()`, and `items()`
# - Create another product using the same structure

# %% [markdown]
# ## 1. Create the Laptop Dictionary
#
# A dictionary is written with curly braces. Each key is connected to a value using a colon.
#
# Our laptop dictionary contains strings, an integer, and a Boolean value.

# %%
laptop = {
    "brand": "Dell",
    "model": "XPS 15",
    "price": 120000,
    "ram": "16GB",
    "storage": "512GB SSD",
    "available": True
}

print("Laptop product:", laptop)
# Out:
# Laptop product: {'brand': 'Dell', 'model': 'XPS 15', 'price': 120000, 'ram': '16GB', 'storage': '512GB SSD', 'available': True}

# %% [markdown]
# ## Dictionary Key Map
#
# | Key | Value | Data type |
# |---|---|---|
# | `brand` | Dell | String |
# | `model` | XPS 15 | String |
# | `price` | 120000 | Integer |
# | `ram` | 16GB | String |
# | `storage` | 512GB SSD | String |
# | `available` | True | Boolean |

# %% [markdown]
# ## 2. Access the Brand, Model, and Price
#
# Dictionary values are accessed by placing a key inside square brackets. Unlike list indexes, dictionary keys describe the information they represent.

# %%
print(laptop["brand"])
print(laptop["model"])
print(laptop["price"])
# Out:
# Dell
# XPS 15
# 120000

# %% [markdown]
# ## 3. Change the Laptop Price
#
# Dictionaries are mutable. Assigning a new value to an existing key replaces its current value.
#
# We will change the price from `120000` to `125000`.

# %%
laptop["price"] = 125000
laptop["ram"] = "32GB"
print(laptop)
# Out:
# {'brand': 'Dell', 'model': 'XPS 15', 'price': 125000, 'ram': '32GB', 'storage': '512GB SSD', 'available': True}

# %% [markdown]
# ## 4. Add Processor and GPU Information
#
# Assigning a value to a key that does not exist creates a new key-value pair.
#
# We will add `processor` and `gpu` specifications to the product.

# %%
laptop["processor"] = "Intel I7"
laptop["gpu"] = "Nvidia RTX 4060"
print(laptop)
# Out:
# {'brand': 'Dell', 'model': 'XPS 15', 'price': 125000, 'ram': '32GB', 'storage': '512GB SSD', 'available': True, 'processor': 'Intel I7', 'gpu': 'Nvidia RTX 4060'}

# %% [markdown]
# ## 5. Upgrade the RAM
#
# We will update the existing `ram` value from `16GB` to `32GB`.

# %%
laptop["ram"] = "32GB"

# %% [markdown]
# ## 6. Remove the Availability Field
#
# The `pop()` method removes a key-value pair and returns the removed value.
#
# We will remove the `available` field and store its former value so we can display what was removed.

# %%
removed = laptop.pop("available")
print(removed)
print(laptop)
# Out:
# True
# {'brand': 'Dell', 'model': 'XPS 15', 'price': 125000, 'ram': '32GB', 'storage': '512GB SSD', 'processor': 'Intel I7', 'gpu': 'Nvidia RTX 4060'}

# %% [markdown]
# ## 7. Print All Keys — `keys()`
#
# The `keys()` method returns a dynamic view containing every key in the dictionary. Converting the view to a list makes the output easier to read.

# %%
print(laptop.keys())
# Out:
# dict_keys(['brand', 'model', 'price', 'ram', 'storage', 'processor', 'gpu'])

# %% [markdown]
# ## 8. Print All Values — `values()`
#
# The `values()` method returns a dynamic view containing every value in the dictionary.

# %%
print(laptop.values())
# Out:
# dict_values(['Dell', 'XPS 15', 125000, '32GB', '512GB SSD', 'Intel I7', 'Nvidia RTX 4060'])

# %% [markdown]
# ## 9. Print All Items — `items()`
#
# The `items()` method returns each dictionary entry as a `(key, value)` tuple. This view is useful when both parts of every entry are needed.

# %%
print(laptop.items())
# Out:
# dict_items([('brand', 'Dell'), ('model', 'XPS 15'), ('price', 125000), ('ram', '32GB'), ('storage', '512GB SSD'), ('processor', 'Intel I7'), ('gpu', 'Nvidia RTX 4060')])

# %% [markdown]
# ## 10. Display the Updated Laptop
#
# The updated product now contains a new price, upgraded RAM, processor information, and GPU information. The availability key has been removed.

# %%
print(laptop)
# Out:
# {'brand': 'Dell', 'model': 'XPS 15', 'price': 125000, 'ram': '32GB', 'storage': '512GB SSD', 'processor': 'Intel I7', 'gpu': 'Nvidia RTX 4060'}

# %% [markdown]
# ## 11. Create a Mobile Phone Dictionary
#
# We can use the same key-value structure to represent another type of product. The mobile-phone dictionary includes identifying information, price, memory, storage, operating system, and availability.

# %%
mobile_phone = {
    "brand" : "Samsung",
    "model" : "Galaxy S25",
    "price" : 9000,
    "ram" : "12GB",
    "storage" : "256GB",
    "OS" : "Android",
    "available" : True
}
print(mobile_phone)
# Out:
# {'brand': 'Samsung', 'model': 'Galaxy S25', 'price': 9000, 'ram': '12GB', 'storage': '256GB', 'OS': 'Android', 'available': True}

# %% [markdown]
# ## Dictionary Method Summary
#
# | Operation | Purpose |
# |---|---|
# | `dictionary["key"]` | Accesses a value |
# | `dictionary["key"] = value` | Adds a new key or updates an existing key |
# | `pop("key")` | Removes a key and returns its value |
# | `keys()` | Returns all keys |
# | `values()` | Returns all values |
# | `items()` | Returns all key-value pairs |

# %% [markdown]
# ## Complete Verification
#
# The following independent cell re-creates the original laptop and performs every required operation in order.

# %%
laptop = {
    "brand": "Dell",
    "model": "XPS 15",
    "price": 120000,
    "ram": "16GB",
    "storage": "512GB SSD",
    "available": True
}

print("Product:", laptop)
print("Brand:", laptop["brand"])
print("Model:", laptop["model"])
print("Price:", laptop["price"])

laptop["price"] = 125000
laptop["processor"] = "Intel Core i7"
laptop["gpu"] = "NVIDIA RTX 4060"
laptop["ram"] = "32GB"
removed_availability = laptop.pop("available")

print("Updated price:", laptop["price"])
print("Processor:", laptop["processor"])
print("GPU:", laptop["gpu"])
print("Updated RAM:", laptop["ram"])
print("Removed availability:", removed_availability)
print("All keys:", laptop.keys())
print("All values:", laptop.values())
print("All items:", laptop.items())
print("Final laptop:", laptop)

mobile_phone = {
    "brand": "Samsung",
    "model": "Galaxy S25",
    "price": 90000,
    "ram": "12GB",
    "storage": "256GB",
    "operating_system": "Android",
    "available": True
}
print("Mobile phone:", mobile_phone)

# %% [markdown]
# ## Practice Challenge
#
# Create a dictionary representing a tablet. Include its brand, model, price, storage, color, and availability. Then update its price, add processor information, remove one field, and print its keys, values, and items.

# %% [markdown]
# ## Conclusion
#
# In this tutorial, we created and updated product dictionaries in Python. We accessed individual values, changed product specifications, added new information, removed a field, and inspected the complete collection of keys, values, and items.
#
# Dictionaries are a natural choice for product data because descriptive keys make each value easy to understand and update.
