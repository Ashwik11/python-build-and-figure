# %% [markdown]
# # Real-World Loop Challenges
#
# **Euron Super30 Assignment**
# **Repository:** `super30-python-loop-task-3`
# **Due:** September 5, 2026, 2:28 PM
#
# This notebook contains 12 independently runnable exercises, solution-planning guidance, test cases, and empty code cells for live coding. Every solution should demonstrate loop-based reasoning rather than shortcuts that bypass the concept being tested.

# %% [markdown]
# ## Learning objectives
#
# By completing this assignment, you will practice:
#
# - Accumulating totals and counts
# - Tracking minimum and maximum values manually
# - Classifying data into non-overlapping ranges
# - Limiting attempts and validating user choices
# - Building lists and dictionaries through iteration
# - Comparing values without sorting shortcuts
# - Using loops in small interactive applications

# %% [markdown]
# ## How to use this notebook
#
# For each question:
#
# 1. Explain the input, expected output, and loop's purpose.
# 2. Describe what must be initialized before the loop.
# 3. Write the solution in the empty code cell while recording.
# 4. Run the suggested successful and unsuccessful or edge test cases.
# 5. Keep each program self-contained so its cell can run independently.
#
# > **Required live demonstrations:** Student marks analysis (Question 4), login attempts (Question 5), character frequency (Question 8), and ATM simulation (Question 12).

# %% [markdown]
# ---
#
# ## Question 1 — Total transaction value without `sum()`
#
# ### Given data
#
# ```python
# transactions = [1200, 450, 800, 1500, 2300, 700, 100]
# ```
#
# ### Problem
# Calculate the total transaction value without using `sum()`.
#
# ### How to approach it
#
# - Create a total accumulator with an appropriate starting value.
# - Iterate through every transaction.
# - Add the current transaction to the running total.
# - Print the final total after the loop finishes.
#
# ### Expected result
# The total transaction value is `7050`.
#
# ### Explain in the video
# Trace the first few updates to the accumulator and explain why the final print belongs after the loop.

# %% [markdown]
# ---
#
# ## Question 2 — Highest and lowest transactions
#
# ### Given data
#
# ```python
# transactions = [1200, 450, 800, 1500, 2300, 700, 100]
# ```
#
# ### Problem
# Find the highest and lowest transaction without using `max()` or `min()`.
#
# ### How to approach it
#
# - Initialize both tracked values from the first element of the non-empty list.
# - Compare every transaction with the current highest value and update it when needed.
# - Independently compare it with the current lowest value and update it when needed.
# - Print both tracked values after all elements have been processed.
#
# ### Expected results
#
# - Highest transaction: `2300`
# - Lowest transaction: `100`
#
# ### Explain in the video
# Explain why initializing from a real list element is safer than assuming zero is a suitable starting value.

# %% [markdown]
# ---
#
# ## Question 3 — Average temperature
#
# ### Given data
#
# ```python
# temperatures = [32, 35, 28, 40, 38, 31, 42]
# ```
#
# ### Problem
# Find the average temperature using loop-based logic.
#
# ### How to approach it
#
# - Use a loop to calculate the total of all temperatures.
# - Determine how many readings are present.
# - Divide the total by the number of readings after the loop.
# - Print the average in a readable format; rounding to two decimal places is acceptable.
#
# ### Expected result
# The exact average is approximately `35.142857`; rounded to two decimal places, it is `35.14`.
#
# ### Explain in the video
# State the average formula and distinguish the running total from the final division.

# %% [markdown]
# ---
#
# ## Question 4 — Student marks analysis
#
# ### Given data
#
# ```python
# marks = [78, 92, 45, 67, 88, 53, 99]
# ```
#
# ### Required categories
#
# - 90 and above
# - 75 through 89
# - 50 through 74
# - Below 50
#
# ### How to approach it
#
# - Initialize one counter for each category.
# - Iterate through the marks once.
# - Use an `if`/`elif`/`else` chain ordered from the highest range downward.
# - Increase exactly one counter for each mark.
# - Print all four totals after the loop.
#
# ### Expected counts
#
# - 90+: `2`
# - 75–89: `2`
# - 50–74: `2`
# - Below 50: `1`
#
# ### Boundary tests
# Also test `90`, `89`, `75`, `74`, `50`, and `49` to prove that every boundary enters the correct category.
#
# ### Explain in the video
# Show why the categories do not overlap and why the order of conditions matters.

# %% [markdown]
# ---
#
# ## Question 5 — Login system with three attempts
#
# ### Problem
# Create a simple login system that permits no more than three password attempts.
#
# ### How to approach it
#
# - Store one expected password for the simulation.
# - Use a loop that can run at most three times.
# - Ask for a password during each iteration.
# - On a correct password, print a success message and stop immediately.
# - After three incorrect attempts, print an access-denied or attempts-exhausted message.
# - A loop `else` can cleanly handle the all-failed outcome.
#
# ### Required tests
#
# - **Successful case:** Enter a wrong password once and then the correct password. Confirm that no further prompt appears.
# - **Unsuccessful case:** Enter an incorrect password three times. Confirm that a fourth attempt is not allowed.
#
# ### Explain in the video
# Trace the attempt count, explain the early exit, and show how the program distinguishes success from exhaustion.

# %% [markdown]
# ---
#
# ## Question 6 — Filter products by price
#
# ### Given data
#
# ```python
# products = {
#     "Laptop": 55000,
#     "Phone": 30000,
#     "Headphones": 2000,
#     "Mouse": 700,
#     "Keyboard": 1500
# }
# ```
#
# ### Problem
# Print only products costing more than ₹2,000.
#
# ### How to approach it
#
# - Iterate through the dictionary's product-price pairs.
# - Compare each price with 2,000 using a strict greater-than condition.
# - Print both the product and price only when the condition passes.
#
# ### Expected products
# Only `Laptop` and `Phone` should be printed. `Headphones` costs exactly ₹2,000, so it must not be included.
#
# ### Explain in the video
# Explain dictionary pair iteration and the difference between “more than” and “at least.”

# %% [markdown]
# ---
#
# ## Question 7 — Accept and store 10 numbers
#
# ### Problem
# Accept exactly 10 numbers from the user and store them in a list using a loop.
#
# ### How to approach it
#
# - Start with an empty list.
# - Repeat the input step exactly 10 times.
# - Convert each input to the intended numeric type.
# - Append each converted number to the list.
# - Print the completed list after the loop.
# - Use the loop position in the prompt so the user knows which entry is being requested.
#
# ### Test expectation
# Confirm that the final list contains 10 values in the same order in which they were entered.
#
# ### Explain in the video
# Explain why the empty list is created before the loop and how one new element is added per iteration.

# %% [markdown]
# ---
#
# ## Question 8 — Character frequency without `Counter`
#
# ### Problem
# Count the frequency of every character in a string without using `Counter`.
#
# ### Example
#
# **Input:** `banana`
#
# ```text
# b -> 1
# a -> 3
# n -> 2
# ```
#
# ### How to approach it
#
# - Read the string from the user.
# - Create an empty dictionary for character counts.
# - Iterate through the string one character at a time.
# - If the character is already a dictionary key, increase its count; otherwise create it with a count of one.
# - After counting, use a second loop to print every character and frequency.
#
# ### Additional test
# Use a string containing a repeated space or uppercase letter and explain whether your program treats it as a separate character.
#
# ### Explain in the video
# Trace each character in `banana` and show how the dictionary changes during the loop.

# %% [markdown]
# ---
#
# ## Question 9 — Second-largest number without `sort()`
#
# ### Problem
# Find the second-largest number in a list without using `sort()`.
#
# ### Assumption
# Treat “second-largest” as the second-largest **distinct** value. Duplicate copies of the maximum do not count as the second-largest value.
#
# ### How to approach it
#
# - Track the largest and second-largest distinct values while iterating.
# - When a new largest value is found, move the old largest into the second-largest position.
# - Otherwise, update the second-largest value only when the current value lies below the largest but above the current second-largest.
# - Ignore duplicate copies of the current largest.
# - Handle a list that does not contain two distinct values.
#
# ### Suggested tests
#
# - `[12, 35, 7, 24, 18]` → `24`
# - `[12, 35, 7, 35, 24]` → `24`
# - `[5, 5, 5]` → no distinct second-largest value
# - `[-8, -2, -5]` → `-5`
#
# ### Explain in the video
# Trace when each tracked value changes and explain why duplicate maxima require careful handling.

# %% [markdown]
# ---
#
# ## Question 10 — Palindrome check using loops
#
# ### Problem
# Check whether a string is a palindrome using loop-based comparison.
#
# ### Comparison rule
# For the basic solution, compare the entered characters exactly. If you choose to ignore letter case or spaces, state and apply that normalization clearly before the loop.
#
# ### How to approach it
#
# - Compare characters at matching positions from the beginning and end.
# - Move inward through only the first half of the string.
# - If any pair differs, mark the string as not a palindrome and stop checking.
# - If no mismatch is found, report that the string is a palindrome.
# - Avoid solving the problem only through reverse slicing; the comparison itself should use a loop.
#
# ### Required tests
#
# - `madam` → palindrome
# - `hello` → not a palindrome
# - A one-character string → palindrome
#
# ### Explain in the video
# Show how the matching indexes are related and trace both a successful and unsuccessful comparison.

# %% [markdown]
# ---
#
# ## Question 11 — Increasing number pattern
#
# ### Required output
#
# ```text
# 1
# 12
# 123
# 1234
# 12345
# ```
#
# ### How to approach it
#
# - Treat the outer-loop iteration as the current row.
# - Use an inner loop to generate the values from 1 through the current row number.
# - Print values on the same line during the inner loop.
# - Move to a new line after each row is complete.
#
# ### Explain in the video
# Trace the outer and inner loops for row 4 and explain the print setting that prevents an unwanted space or newline between digits.

# %% [markdown]
# ---
#
# ## Question 12 — Basic ATM simulation
#
# ### Problem
# Create an ATM program that repeatedly allows the user to:
#
# 1. Check balance
# 2. Deposit money
# 3. Withdraw money
# 4. Exit
#
# ### Recommended organization
#
# - Store the current balance in one clearly named variable.
# - Put the repeating menu inside a loop that runs until the user selects Exit.
# - Use a clean conditional branch for each menu choice.
# - To avoid one unreadable block, separate display, deposit, and withdrawal responsibilities into small functions if functions are permitted in your current module.
# - Accept only positive deposit and withdrawal amounts.
# - Reject a withdrawal that exceeds the available balance.
# - Print a helpful message for an invalid menu option.
# - Update the balance only after a valid transaction.
#
# ### Required test flow
#
# **Successful cases:**
#
# - Check the starting balance.
# - Deposit a positive amount and confirm that the balance increases.
# - Withdraw an affordable positive amount and confirm that the balance decreases.
# - Exit and confirm that the menu stops.
#
# **Unsuccessful cases:**
#
# - Attempt to withdraw more than the available balance.
# - Enter a zero or negative transaction amount.
# - Enter an invalid menu choice.
#
# ### Explain in the video
# Explain the menu loop, how each choice changes or preserves state, and why the exit choice terminates the application.

# %% [markdown]
# ---
#
# ## Final verification checklist
#
# ### Code
#
# - [ ] All 12 programs run independently.
# - [ ] Question 1 does not use `sum()`.
# - [ ] Question 2 does not use `max()` or `min()`.
# - [ ] All marks at category boundaries are counted correctly.
# - [ ] The login system never allows more than three attempts.
# - [ ] Headphones are excluded because ₹2,000 is not more than ₹2,000.
# - [ ] Question 7 collects exactly 10 numbers.
# - [ ] Question 8 does not use `Counter`.
# - [ ] Question 9 does not use `sort()` and handles duplicates.
# - [ ] The palindrome decision is produced through loop-based comparison.
# - [ ] ATM balance changes only after valid transactions.
# - [ ] All cells run from top to bottom without errors.
#
# ### GitHub repository
#
# - [ ] Repository is public and named exactly `super30-python-loop-task-3`.
# - [ ] Programs are independently executable.
# - [ ] A README lists all question numbers and briefly explains each approach.
# - [ ] Sample inputs and outputs are included where applicable.
#
# ### YouTube video
#
# - [ ] Demonstrate the login attempt system.
# - [ ] Demonstrate character frequency counting.
# - [ ] Demonstrate student marks analysis.
# - [ ] Demonstrate the ATM simulation.
# - [ ] Show both successful and unsuccessful cases.
# - [ ] Explain logic, execution flow, input, and output.
# - [ ] Add the public GitHub repository link to the video description.
