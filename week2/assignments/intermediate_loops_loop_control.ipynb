# %% [markdown]
# # Intermediate Loops & Loop Control
#
# **Euron Super30 Assignment**
# **Repository:** `super30-python-loop-task-2`
# **Due:** September 5, 2026, 2:28 PM
#
# This notebook provides the questions, planning guidance, test cases, and empty code cells for live coding. Every solution should use loop-based logic and demonstrate the specific concept being tested.

# %% [markdown]
# ## Learning objectives
#
# By completing this assignment, you will practice:
#
# - Repeating tasks with `for` and `range()`
# - Skipping an iteration with `continue`
# - Ending a loop early with `break`
# - Using the `else` clause of a loop
# - Producing numbered output with `enumerate()`
# - Building patterns and tables with nested loops
# - Tracking values without collection shortcuts
# - Testing whether numbers are prime

# %% [markdown]
# ## How to use this notebook
#
# For each question:
#
# 1. State the expected behavior before writing code.
# 2. Explain which loop feature the problem is testing.
# 3. Write the solution in the empty code cell while recording.
# 4. Run the suggested test and explain the execution flow.
# 5. Add brief comments around important decisions—not every obvious line.
#
# > **Required live demonstrations:** Questions 1 (`continue`), 2 (`break`), 3 (`for-else`), 7 (nested loops), and 11 or 12 (prime-number logic) together satisfy the five required video categories.

# %% [markdown]
# ---
#
# ## Question 1 — Skip multiples of 5 with `continue`
#
# ### Problem
# Print numbers from 1 through 100, but skip every number divisible by 5 using `continue`.
#
# ### How to approach it
#
# - Generate every number from 1 through 100.
# - Test whether the current number is divisible by 5.
# - When the condition is true, use `continue` so the print statement is skipped for that iteration.
# - Print all remaining numbers.
#
# ### Test expectation
# The output should contain `1, 2, 3, 4, 6, ...` and should not contain `5`, `10`, `15`, or any other multiple of 5.
#
# ### Explain in the video
# Trace the iterations for 4, 5, and 6 to show that `continue` skips only the rest of the current iteration—not the entire loop.

# %% [markdown]
# ---
#
# ## Question 2 — Stop at the first multiple of both 7 and 11
#
# ### Problem
# Iterate from 1 through 100 and stop when you encounter the first number divisible by both 7 and 11.
#
# ### How to approach it
#
# - Check each number in increasing order.
# - Build one condition that requires divisibility by 7 **and** by 11.
# - When a number satisfies both tests, print it and use `break` to stop the loop immediately.
#
# ### Expected result
# The program should stop at `77`, the first value in the range divisible by both numbers.
#
# ### Explain in the video
# Explain why the condition needs `and`, why the search order guarantees the first match, and what would happen without `break`.

# %% [markdown]
# ---
#
# ## Question 3 — Search a list using `for-else`
#
# ### Problem
# Search for a user-provided number inside a list. Print exactly:
#
# - `Number Found` when the value exists
# - `Number Not Found` when the value does not exist
#
# Use a `for-else` structure.
#
# ### How to approach it
#
# - Define a list of numbers and read the search value from the user.
# - Compare the target with each list element.
# - On a match, print the success message and exit the loop with `break`.
# - Attach `else` to the `for` loop; it should run only when the loop completes without a `break`.
#
# ### Sample tests
# Run the program twice: once with a value present in the list and once with a value absent from it.
#
# ### Explain in the video
# Emphasize that this `else` belongs to the loop, not to the comparison, and explain precisely when it executes.

# %% [markdown]
# ---
#
# ## Question 4 — Number names with `enumerate()`
#
# ### Given data
#
# ```python
# names = ["Aman", "Ravi", "Sudhanshu", "Priya", "Anjali"]
# ```
#
# ### Required output
#
# ```text
# 1 Aman
# 2 Ravi
# 3 Sudhanshu
# 4 Priya
# 5 Anjali
# ```
#
# ### How to approach it
#
# - Iterate with `enumerate()` so every name is paired with a position.
# - Configure the numbering to begin at 1 instead of the default 0.
# - Unpack and print the position and name.
#
# ### Explain in the video
# Explain what `enumerate()` produces and why it is clearer than manually maintaining a counter here.

# %% [markdown]
# ---
#
# ## Question 5 — Increasing star pattern
#
# ### Required output
#
# ```text
# *
# **
# ***
# ****
# *****
# ```
#
# ### How to approach it
#
# - Think of each loop iteration as one output row.
# - Let the row number determine how many stars are printed.
# - Increase the star count from 1 through 5.
#
# ### Explain in the video
# Connect the loop variable to the number of stars on each row and show why five iterations create five lines.

# %% [markdown]
# ---
#
# ## Question 6 — Decreasing star pattern
#
# ### Required output
#
# ```text
# *****
# ****
# ***
# **
# *
# ```
#
# ### How to approach it
#
# - Begin with five stars and reduce the count by one per row.
# - Configure `range()` with a negative step.
# - Remember that the stopping value is excluded even when counting downward.
#
# ### Explain in the video
# Explain the start, stop, and step values and why the final row still contains one star.

# %% [markdown]
# ---
#
# ## Question 7 — Multiplication tables from 1 to 10
#
# ### Problem
# Generate multiplication tables from 1 to 10 using nested loops.
#
# ### How to approach it
#
# - Use the outer loop to select the current table number.
# - Use the inner loop to move through that table's multipliers.
# - Calculate and print one multiplication fact during each inner-loop iteration.
# - Optionally print a blank line after each complete table to improve readability.
#
# ### Test expectation
# Verify that the output starts with the table of 1, ends with the table of 10, and contains the expected number of equations per table.
#
# ### Explain in the video
# Show that the inner loop completes all its iterations for every single iteration of the outer loop.

# %% [markdown]
# ---
#
# ## Question 8 — Multiples of both 3 and 5
#
# ### Problem
# Find all numbers between 1 and 200 that are divisible by both 3 and 5.
#
# ### How to approach it
#
# - Iterate through the complete inclusive range.
# - Check both divisibility conditions for each number.
# - Print only the values that satisfy both conditions.
#
# ### Test expectation
# The sequence should begin with `15`, continue with `30`, and end with `195`.
#
# ### Explain in the video
# Explain why satisfying only one condition is insufficient and how the logical operator combines the tests.

# %% [markdown]
# ---
#
# ## Question 9 — Remove duplicates without `set()`
#
# ### Problem
# Given a list containing duplicate elements, create another list containing only unique elements without using `set()`.
#
# ### Suggested test data
#
# ```python
# items = [10, 20, 10, 30, 20, 40, 10]
# ```
#
# ### How to approach it
#
# - Create an empty list for the unique results.
# - Visit each element in the original list.
# - Add the element only when it is not already present in the result list.
# - Print the completed result after the loop.
#
# ### Test expectation
# For the suggested data, the result should preserve the first occurrence order: `[10, 20, 30, 40]`.
#
# ### Explain in the video
# Trace one repeated value and show why it is not appended a second time.

# %% [markdown]
# ---
#
# ## Question 10 — Count positive numbers, negative numbers, and zeros
#
# ### Given data
#
# ```python
# numbers = [10, -4, 8, -2, 0, 15, -9, 21]
# ```
#
# ### How to approach it
#
# - Create three counters and initialize each to zero.
# - Iterate through the list once.
# - Use mutually exclusive conditions to classify the current number as positive, negative, or zero.
# - Increase exactly one counter per iteration.
# - Print all three totals after the loop.
#
# ### Expected counts
#
# - Positive numbers: `4`
# - Negative numbers: `3`
# - Zeros: `1`
#
# ### Explain in the video
# Explain why zero is neither positive nor negative and why an `if`/`elif`/`else` chain prevents double-counting.

# %% [markdown]
# ---
#
# ## Question 11 — Determine whether a number is prime
#
# ### Problem
# Use a loop to determine whether a user-provided integer is prime.
#
# ### Prime-number rule
# A prime number is greater than 1 and has exactly two positive factors: 1 and itself.
#
# ### How to approach it
#
# - Handle values less than 2 as not prime.
# - Test possible divisors using a loop.
# - If any divisor produces no remainder, the number is not prime and the search can stop.
# - If the loop completes without finding a divisor, the number is prime.
# - A `for-else` structure is a natural fit, though a clearly explained flag-based solution can also work.
#
# ### Sample tests
#
# - `2` → prime
# - `17` → prime
# - `21` → not prime
# - `1` → not prime
#
# ### Explain in the video
# Define a prime number, identify the divisor range, and show how finding one valid divisor proves a number is composite.

# %% [markdown]
# ---
#
# ## Question 12 — Print all prime numbers from 1 to 100
#
# ### Problem
# Print every prime number between 1 and 100.
#
# ### How to approach it
#
# - Use an outer loop to select each candidate number in the required range.
# - Exclude values below 2 because they are not prime.
# - For each candidate, use an inner loop to search for a divisor.
# - Stop checking the current candidate as soon as a divisor is found.
# - Print the candidate only when no divisor was found.
#
# ### Test expectation
# The output should begin with `2, 3, 5, 7`, contain no `1`, and end with `97`.
#
# ### Explain in the video
# Separate the responsibilities of the outer and inner loops and trace one prime candidate and one composite candidate.

# %% [markdown]
# ---
#
# ## Final verification checklist
#
# ### Code
#
# - [ ] All 12 questions have working loop-based solutions.
# - [ ] Question 1 visibly uses `continue`.
# - [ ] Question 2 visibly uses `break`.
# - [ ] Question 3 uses `for-else` and prints the exact required messages.
# - [ ] Question 4 uses `enumerate()` and numbering begins at 1.
# - [ ] Question 7 uses nested loops.
# - [ ] Question 9 does not use `set()`.
# - [ ] Prime logic correctly classifies 0, 1, 2, primes, and composite numbers.
# - [ ] All notebook cells run from top to bottom without errors.
#
# ### GitHub repository
#
# - [ ] Repository is public and named exactly `super30-python-loop-task-2`.
# - [ ] The completed notebook or Python source files are included.
# - [ ] `README.md` lists every question number.
# - [ ] Each README entry briefly explains the approach.
# - [ ] Sample inputs and outputs are documented where applicable.
#
# ### YouTube video
#
# - [ ] Demonstrate at least five programs live.
# - [ ] Include one `continue` example.
# - [ ] Include one `break` example.
# - [ ] Include one `for-else` example.
# - [ ] Include one nested-loop example.
# - [ ] Include one prime-number example.
# - [ ] Explain logic, execution flow, input, output, and test cases.
# - [ ] Add the public GitHub repository link to the video description.
