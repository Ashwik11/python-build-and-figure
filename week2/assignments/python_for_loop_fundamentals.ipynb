# %% [markdown]
# # Python `for` Loop Fundamentals

# %% [markdown]
# ## Learning objectives
#
# By completing this assignment, you will practice:
#
# - Iterating with `for` loops
# - Generating number sequences with `range()`
# - Applying conditions inside loops
# - Accumulating totals and building new values
# - Iterating through strings and collections
# - Solving problems without shortcuts such as `max()`, `reversed()`, slicing with `[::-1]`, or a built-in factorial function

# %% [markdown]
# ---
#
# ## Question 1 — Print numbers from 1 to 100
#
# ### Problem
# Write a program that prints every integer from 1 through 100 using a `for` loop.
#
# ### How to approach it
#
# - Use `range()` to generate the required sequence.
# - Remember that the ending value supplied to `range()` is excluded.
# - Print the current number during each iteration.
#
# ### Test expectation
# The output should begin with `1`, end with `100`, and include every integer in between.

# %% [markdown]
# ---
#
# ## Question 2 — Print even numbers from 1 to 100
#
# ### Problem
# Print all even numbers from 1 through 100.
#
# ### How to approach it
#
# - Loop through the required numeric range.
# - Use the remainder operator to determine whether each number is divisible by 2.
# - Print a number only when it satisfies the even-number condition.
#
# ### Test expectation
# The output should begin with `2`, continue as `4, 6, 8, ...`, and end with `100`.

# %% [markdown]
# ---
#
# ## Question 3 — Print odd numbers from 1 to 100
#
# ### Problem
# Print all odd numbers from 1 through 100.
#
# ### How to approach it
#
# - Loop through the numbers from 1 to 100.
# - Check which numbers are not evenly divisible by 2.
# - Print only the numbers that satisfy the odd-number condition.
#
# ### Test expectation
# The output should begin with `1`, continue as `3, 5, 7, ...`, and end with `99`.

# %% [markdown]
# ---
#
# ## Question 4 — Multiplication table from 1 to 20
#
# ### Problem
# Take an integer `n` from the user and print its multiplication table from 1 through 20.
#
# ### How to approach it
#
# - Read a value with `input()` and convert it to an integer.
# - Loop through the multipliers 1 to 20.
# - During each iteration, multiply `n` by the current multiplier.
# - Display the number, multiplier, and product in a readable equation.
#
# ### Sample test case
#
# **Input:** `5`
# **Expected first line:** `5 x 1 = 5`
# **Expected last line:** `5 x 20 = 100`
#
# Identify which value stays fixed, which value changes, and how the product is recalculated on every iteration.

# %% [markdown]
# ---
#
# ## Question 5 — Sum of numbers from 1 to n
#
# ### Problem
# Take an integer `n` and calculate the sum of all integers from 1 through `n` using a loop.
#
# ### How to approach it
#
# - Read and convert the user's input.
# - Create an accumulator with an appropriate starting value.
# - Loop from 1 through `n`.
# - Add the current number to the accumulator during each iteration.
# - Print the accumulator after the loop finishes.
#
# ### Sample test case
#
# **Input:** `5`
# **Calculation:** `1 + 2 + 3 + 4 + 5`
# **Expected output:** `15`
#
# Trace the accumulator after each iteration and clarify why the final result is printed outside the loop.

# %% [markdown]
# ---
#
# ## Question 6 — Factorial without a built-in factorial function
#
# ### Problem
# Calculate the factorial of a number using a loop. Do not use a built-in factorial function.
#
# ### How to approach it
#
# - Read a non-negative integer from the user.
# - Create an accumulator using the multiplicative identity.
# - Multiply the accumulator by every integer from 1 through the input number.
# - Print the result after the loop.
# - Remember the special case: `0!` equals `1`.
#
# ### Sample test cases
#
# - **Input:** `5` → **Expected output:** `120`
# - **Input:** `0` → **Expected output:** `1`
#
# Understand why the accumulator must not begin at zero

# %% [markdown]
# ---
#
# ## Question 7 — Numbers divisible by 3
#
# ### Given data
#
# ```python
# numbers = [12, 7, 9, 20, 33, 42, 8, 15]
# ```
#
# ### Problem
# Print only the numbers that are divisible by 3.
#
# ### How to approach it
#
# - Iterate directly through the list.
# - Test each number using the remainder operator.
# - Print the number only when division by 3 leaves no remainder.
#
# ### Test expectation
# The output should preserve the order of all qualifying values from the original list.
#
# Show one value that passes the condition and one value that does not.

# %%
numbers = [12, 7, 9, 20, 33, 42, 8, 15]

# %% [markdown]
# ---
#
# ## Question 8 — Languages and their lengths
#
# ### Given data
#
# ```python
# languages = ["Python", "Java", "C++", "JavaScript", "Go"]
# ```
#
# ### Problem
# Print every language together with its length.
#
# ### How to approach it
#
# - Iterate through the list one language at a time.
# - Use the string-length function on the current language.
# - Print both values in a clear, consistent format.
#
# ### Sample output format
# `Python: 6`
#
#  each list element is a string and that punctuation characters, such as the plus signs in `C++`, also count toward its length.

# %%
languages = ["Python", "Java", "C++", "JavaScript", "Go"]

# %% [markdown]
# ---
#
# ## Question 9 — Iterate through a dictionary
#
# ### Given data
#
# ```python
# student = {
#     "name": "Rahul",
#     "age": 22,
#     "course": "Data Science",
#     "city": "Bangalore"
# }
# ```
#
# ### Problem
# Iterate through the dictionary and print every key and its corresponding value.
#
# ### How to approach it
#
# - Use the dictionary method that provides key-value pairs.
# - Unpack each pair into two loop variables.
# - Print the key and value together in a readable format.
#
# ### Sample output format
# `name: Rahul`
#
# Understand the difference between a dictionary key and value and how pair unpacking works inside the loop.

# %%
student = {
    "name": "Rahul",
    "age": 22,
    "course": "Data Science",
    "city": "Bangalore"
}

# %% [markdown]
# ---
#
# ## Question 10 — Count vowels in a string
#
# ### Problem
# Count how many vowels exist in a string entered by the user.
#
# ### How to approach it
#
# - Read a string from the user.
# - Create a counter starting at zero.
# - Iterate through the string character by character.
# - Check whether each character belongs to the set of vowels.
# - Make the comparison case-insensitive so uppercase vowels are counted too.
# - Increase the counter for every match and print it after the loop.
#
# ### Sample test case
#
# **Input:** `Education`
# **Expected output:** `5`
#
# Trace which letters are counted and clarify why the counter is updated only when the condition is true.

# %%
user_string = input()

# %% [markdown]
# ---
#
# ## Question 11 — Reverse a string using a `for` loop
#
# ### Problem
# Reverse a user-provided string without using `[::-1]` or `reversed()`.
#
# ### How to approach it
#
# - Read the original string from the user.
# - Start with an empty result string.
# - Iterate through the original string one character at a time.
# - Place each current character on the correct side of the result so the order gradually reverses.
# - Print the completed result after the loop.
#
# ### Sample test case
#
# **Input:** `Python`
# **Expected output:** `nohtyP`
#
# Trace how the result changes after each character and confirm that neither prohibited shortcut is used.

# %%
user_input = input()

# %% [markdown]
# ---
#
# ## Question 12 — Find the largest number without `max()`
#
# ### Problem
# Find the largest number in a list without using the built-in `max()` function.
#
# ### How to approach it
#
# - Use a non-empty list for the test.
# - Initialize the current-largest value from an actual list element.
# - Iterate through the list and compare every number with the current-largest value.
# - Update the stored value whenever a larger number is found.
# - Print the stored value after all comparisons are complete.
#
# ### Sample test case
#
# **List:** `[14, 3, 27, 9, 18]`
# **Expected output:** `27`

# %%
l = [14, 3, 27, 9, 18]

# %% [markdown]
# ---
